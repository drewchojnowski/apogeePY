# %%
# %matplotlib inline

# %%
import apogeespec as ap

# %%
f='test.fits'

# %%
x=ap.splot(f)

# %%
f='apVisit-r5-6898-56437-231.fits'

# %% [markdown]
# ## MWC 922 is more fun too look at.

# %%
x=ap.splot(f)

# %% [markdown]
# ## if you plot this up in a normal ipython session, tapping a key on the keyboard will print some information to the terminal. For example, I clicked on the center of Br11, and it told me my click was -0.776 angstroms from the Br11 rest wavelength. Now I'll go ahead and apply that shift and replot.

# %%
x=ap.splot(f,xshift=-0.776)

# %% [markdown]
# ## Want to see where the airglow lines are?

# %%
x=ap.splot(f,xshift=-0.776,mark_sky=True)

# %% [markdown]
# ## Want to see the spectrum without normalization?

# %%
x=ap.splot(f,xshift=-0.776,mark_sky=True,do_cont=False)

# %% [markdown]
# ## Want to try changing the continuum fit order?

# %%
x=ap.splot(f,xshift=-0.776,mark_sky=True,cont_ord=9)
# Out:
# /usr/lib/python2.7/dist-packages/numpy/lib/polynomial.py:587: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %% [markdown]
# ## That looked bad. Let's try order 3 (default order = 5)

# %%
x=ap.splot(f,xshift=-0.776,mark_sky=True,cont_ord=3)

# %% [markdown]
# ## Maybe it's best to do the normalization chip-by-chip?

# %%
x=ap.splot(f,xshift=-0.776,mark_sky=True,cont_ord=3,do_cont_chips=True)

# %% [markdown]
# ## Nope, that looks like crap. How about higher order for the chip-by-chip normalization?

# %%
x=ap.splot(f,xshift=-0.776,mark_sky=True,cont_ord=5,do_cont_chips=True)
# Out:
# /usr/lib/python2.7/dist-packages/numpy/lib/polynomial.py:587: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %% [markdown]
# ## Still looks like crap. Need to normalize around the emission lines.
